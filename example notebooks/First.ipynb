# %%
import matplotlib.pyplot as plt
x=[-2,-1,0,1,2]
y=[4,1,0,1,4]

# %%
plt.plot(x,y)

# %%
! ping www.google.com
# Out:
# Pinging www.google.com [142.250.75.164] with 32 bytes of data:
# Reply from 142.250.75.164: bytes=32 time=10ms TTL=119
# Reply from 142.250.75.164: bytes=32 time=6ms TTL=119
# Reply from 142.250.75.164: bytes=32 time=11ms TTL=119
# Reply from 142.250.75.164: bytes=32 time=7ms TTL=119
#
# Ping statistics for 142.250.75.164:
#     Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),
# Approximate round trip times in milli-seconds:
#     Minimum = 6ms, Maximum = 11ms, Average = 8ms
