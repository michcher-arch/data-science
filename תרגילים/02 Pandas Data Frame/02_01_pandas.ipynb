# %%
import pandas as pd

data = {
    'StudentID': [1, 2, 3, 4, 5],
    'Name': ['John', 'Emily', 'Robert', 'Linda', 'Michael'],
    'Age': [21, 22, 20, 23, 22],
    'Gender': ['M', 'F', 'M', 'F', 'M'],
    'GradeMath': [85, 90, 78, 92, 88],
    'GradeEnglish': [75, 92, 80, 88, 85],
    'GradeScience': [88, 85, 90, 84, 89]
}

df = pd.DataFrame(data)

df
# Out:
#    StudentID     Name  Age Gender  GradeMath  GradeEnglish  GradeScience
# 0          1     John   21      M         85            75            88
# 1          2    Emily   22      F         90            92            85
# 2          3   Robert   20      M         78            80            90
# 3          4    Linda   23      F         92            88            84
# 4          5  Michael   22      M         88            85            89

# %%
# write code here

# %%
# get data frame info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   StudentID     5 non-null      int64
#  1   Name          5 non-null      object
#  2   Age           5 non-null      int64
#  3   Gender        5 non-null      object
#  4   GradeMath     5 non-null      int64
#  5   GradeEnglish  5 non-null      int64
#  6   GradeScience  5 non-null      int64
# dtypes: int64(5), object(2)
# memory usage: 408.0+ bytes

# %%
# write code here

# %%
# get first 3 rows - option 1
# Out:
#    StudentID    Name  Age Gender  GradeMath  GradeEnglish  GradeScience
# 0          1    John   21      M         85            75            88
# 1          2   Emily   22      F         90            92            85
# 2          3  Robert   20      M         78            80            90

# %%
# write code here

# %%
# get first 3 rows - option 2
# Out:
#    StudentID    Name  Age Gender  GradeMath  GradeEnglish  GradeScience
# 0          1    John   21      M         85            75            88
# 1          2   Emily   22      F         90            92            85
# 2          3  Robert   20      M         78            80            90

# %%
# write code here

# %%
# get columns labels
# Out:
# Index(['StudentID', 'Name', 'Age', 'Gender', 'GradeMath', 'GradeEnglish',
#        'GradeScience'],
#       dtype='object')

# %%
# write code here

# %%
# get a single column name
# Out:
# 'Gender'

# %%
# write code here

# %%
# show column option 1
# Out:
# 0       John
# 1      Emily
# 2     Robert
# 3      Linda
# 4    Michael
# Name: Name, dtype: object

# %%
# write code here

# %%
# show column option 2
# Out:
# 0       John
# 1      Emily
# 2     Robert
# 3      Linda
# 4    Michael
# Name: Name, dtype: object

# %%
# write code here

# %%
# show column value
# Out:
# 'Linda'

# %%
# write code here

# %%
# sub data frame
# Out:
#       Name  Age
# 0     John   21
# 1    Emily   22
# 2   Robert   20
# 3    Linda   23
# 4  Michael   22

# %% [markdown]
# Write the function max_grade:
# 1. The function gets 2 parameters: column name (GradeMath, GradeEnglish, GradeSience) and dataframe
# 2. The function searchs for the student that has the highest score in this column and prints the student name. Assume that there is only one student.
# 3. The function returns a new dataframe object that contains only the above student row.

# %%
# Write code here:
def max_grade(column_name, dataframe):
  pass
